# %% [markdown]
# ## **Get_CRM_Data_Into_Custom_Bronze_Schema**

# %%
df_crm_companies = spark.read.format("csv").option("header","true").load("Files/HubspotCrm/Companies.csv")
# df_crm_companies now is a Spark DataFrame containing CSV data from "Files/HubspotCrm/Companies.csv".
df_crm_companies.write.mode("overwrite").saveAsTable("Ops_Bronze.crm_companies")
# Out:
# StatementMeta(, ffe65473-dc37-4f50-98db-97f1e3b2ea15, 5, Finished, Available, Finished)

# %%
df_crm_customers = spark.read.format("csv").option("header","true").load("Files/HubspotCrm/Customers.csv")
# df_crm_customers now is a Spark DataFrame containing CSV data from "Files/HubspotCrm/Customers.csv".
df_crm_customers.write.mode("overwrite").saveAsTable("Ops_Bronze.crm_customers")
# Out:
# StatementMeta(, ffe65473-dc37-4f50-98db-97f1e3b2ea15, 7, Finished, Available, Finished)

# %% [markdown]
# ## **Get_ERP_Data_Into_Custom_Bronze_Schema**

# %%
# Read the Product data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_product table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Production_Product")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_product")
# Out:
# StatementMeta(, f3f27b65-f9f0-4ce2-940c-517a8b0c160d, 5, Finished, Available, Finished)

# %%
# Read the Product Category data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_productcategory table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Production_ProductCategory")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_productcategory")
# Out:
# StatementMeta(, f3f27b65-f9f0-4ce2-940c-517a8b0c160d, 6, Finished, Available, Finished)

# %%
# Read the Product Model data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_productmodel table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Production_ProductModel")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_productmodel")
# Out:
# StatementMeta(, f3f27b65-f9f0-4ce2-940c-517a8b0c160d, 7, Finished, Available, Finished)

# %%
# Read the Product Subcategory data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_productsubcategory table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Production_ProductSubcategory")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_productsubcategory")
# Out:
# StatementMeta(, f3f27b65-f9f0-4ce2-940c-517a8b0c160d, 8, Finished, Available, Finished)

# %%
# Read sales order detail data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_salesorderdetail table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Sales_SalesOrderDetail")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_salesorderdetail")
# Out:
# StatementMeta(, 57b37a67-15ec-4976-aa21-3109c5f9ea20, 3, Finished, Available, Finished)

# %%
# Read sales order header data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_salesorderheader table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Sales_SalesOrderHeader")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_salesorderheader")
# Out:
# StatementMeta(, f3f27b65-f9f0-4ce2-940c-517a8b0c160d, 10, Finished, Available, Finished)

# %%
# Read sales order header sales reason data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_salesorderheadersalesreason table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Sales_SalesOrderHeaderSalesReason")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_salesorderheadersalesreason")
# Out:
# StatementMeta(, f3f27b65-f9f0-4ce2-940c-517a8b0c160d, 12, Finished, Available, Finished)

# %%
# Read sales order header sales reason data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_salesreason table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Sales_SalesReason")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_salesreason")
# Out:
# StatementMeta(, f3f27b65-f9f0-4ce2-940c-517a8b0c160d, 13, Finished, Available, Finished)

# %%
# Read sales territory data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_salesterritory table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Sales_SalesTerritory")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_salesterritory")
# Out:
# StatementMeta(, f3f27b65-f9f0-4ce2-940c-517a8b0c160d, 14, Finished, Available, Finished)

# %%
# Read sales special offer data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_salesspecialoffer table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Sales_SpecialOffer")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_salesspecialoffer")
# Out:
# StatementMeta(, f3f27b65-f9f0-4ce2-940c-517a8b0c160d, 15, Finished, Available, Finished)

# %%
# Read sales customer data refered as shortcut from default schema and load it into Ops_Bronze Custom Schema under erp_salescustomer table

df = spark.sql("SELECT * FROM AdventureWorks_Lakehouse.dbo.Sales_Customer")
df.write.mode("overwrite").saveAsTable("Ops_Bronze.erp_salescustomer")
# Out:
# StatementMeta(, 2e5bbaa7-c705-45ac-a134-f33e20c0e715, 3, Finished, Available, Finished)

# %% [markdown]
# ## **Get_SocialReview_Data_Into_Custom_Bronze_Schema**

# %%
df_product_socialtwitterreviews = spark.read.format("csv").option("header","true").load("Files/SocialPlatform/product-review-adventure-works/product_reviews_twitter.csv")
# df now is a Spark DataFrame containing CSV data from "Files/SocialPlatform/product-review-adventure-works/product_reviews_twitter.csv".
df_product_socialtwitterreviews.write.mode("overwrite").saveAsTable("Ops_Bronze.social_twitterreviews")
